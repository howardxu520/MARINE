# %%
import pandas as pd

# %%
all_edit_info_pd = pd.read_csv('only_5_cells_test/all_edit_info.tsv', sep='\t')

# %%
all_edit_info_pd = all_edit_info_pd[all_edit_info_pd['position'] == 3000527]

# %%
all_edit_info_pd.head()
# Out:
#               barcode_position             barcode  contig  position ref alt  \
# 16  GGGACCTTCGAGCCAC-1:3000527  GGGACCTTCGAGCCAC-1       9   3000527   T   C
# 17  GGGACCTTCGAGCCAC-1:3000527  GGGACCTTCGAGCCAC-1       9   3000527   T   C
# 18  GGGACCTTCGAGCCAC-1:3000527  GGGACCTTCGAGCCAC-1       9   3000527   T   C
# 19  GGGACCTTCGAGCCAC-1:3000527  GGGACCTTCGAGCCAC-1       9   3000527   T   A
# 20  GGGACCTTCGAGCCAC-1:3000527  GGGACCTTCGAGCCAC-1       9   3000527   T   C
#
#                                     read_id strand  dist_from_end  \
# 16   A01535:287:H3JJHDSX7:1:1616:4463:31641      +             46
# 17    A01535:287:H3JJHDSX7:1:1333:1289:8015      +             48
# 18   A01535:287:H3JJHDSX7:2:1624:24044:8124      +             50
# 19  A01535:287:H3JJHDSX7:1:2250:27552:14199      +             40
# 20   A01535:287:H3JJHDSX7:1:1570:27326:7326      +             36
#
#     base_quality  mapping_quality          barcode_position.1  coverage source
# ...

# %%
filtered_site_info = pd.read_csv('only_5_cells_test/final_filtered_site_info_annotated.tsv', sep='\t')

# %%
filtered_site_info[filtered_site_info.position == 3000527]
# Out:
#                                site_id             barcode  contig  position  \
# 2   GGGACCTTCGAGCCAC-1_9_3000527_T_C_+  GGGACCTTCGAGCCAC-1       9   3000527
# 13  GCTCAAACAAGGTCTT-1_9_3000527_T_A_+  GCTCAAACAAGGTCTT-1       9   3000527
# 16  GCTCAAACAAGGTCTT-1_9_3000527_T_C_+  GCTCAAACAAGGTCTT-1       9   3000527
# 32  GATCCCTCAGTAACGG-1_9_3000527_T_C_+  GATCCCTCAGTAACGG-1       9   3000527
# 36  GGGACCTTCGAGCCAC-1_9_3000527_T_A_+  GGGACCTTCGAGCCAC-1       9   3000527
# 38  GTTCATTAGTCATTGC-1_9_3000527_T_C_+  GTTCATTAGTCATTGC-1       9   3000527
# 56  TACCTGCAGACTTGTC-1_9_3000527_T_C_+  TACCTGCAGACTTGTC-1       9   3000527
#
#    ref alt strand  count  coverage conversion feature_name feature_strand  \
# 2    T   C      +     10      12.0        T>C            .              .
# 13   T   A      +      1       7.0        T>A            .              .
# 16   T   C      +      6       7.0        T>C            .              .
# ...
